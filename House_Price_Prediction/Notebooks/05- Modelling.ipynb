# %% [markdown]
# # Data Modelling

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import cross_validate

# %% [markdown]
# ### Model Load

# %%
expected_model_version = '1.0'
model_path = r'..\Model\my_model.pkl'
if os.path.exists(model_path):
    with open(model_path, 'rb') as f:
        model = pickle.load(f)
   # if model.version != expected_model_version:
    #    print("Expected model version doesn't match version loaded")
    #if model.sklearn_version != sklearn_version:
     #   print("Warning: model created under different sklearn version")
else:
    print("Expected model not found")

# %% [markdown]
# ### Data Load

# %%
test_data = pd.read_csv(r'..\Data\test_data.csv', index_col = 0)
test_data = test_data.reset_index()
X_test = test_data.drop(columns = ['index'], axis = 1)
X_test
# Out:
#              Id      Price  Bedroom_Count  Bathroom_Count  Sqft_Living  \
# 0    1445500100   900000.0              5            2.25         2510
# 1    5515600163   420000.0              5            2.25         3070
# 2    7300400320   340000.0              4            2.50         2810
# 3     251200240   491500.0              4            2.75         2100
# 4    1025039086  1875000.0              3            2.50         3280
# ..          ...        ...            ...             ...          ...
# 210  4302200625   335000.0              3            1.75         1790
# 211  8562780290   329950.0              2            2.25         1260
# 212  1762600090  1211000.0              4            2.50         3430
# 213  2867300190   363000.0              4            2.50         3753
# 214  5366200330   470000.0              4            2.00         1500
#
#      Sqft_Plot  Floor_Count  Waterfront  View  Condition  ...  \
# 0        35691          1.0           0     0          3  ...
# 1        64033          1.0           0     0          3  ...
# 2         6481          2.0           0     0          3  ...
# 3         7236          1.0           0     0          3  ...
# 4        29111          2.0           1     3          3  ...
# ..         ...          ...         ...   ...        ...  ...
# 210       5120          1.0           0     0          4  ...
# 211       1032          2.0           0     0          3  ...
# 212      35120          2.0           0     0          3  ...
# 213       7204          2.0           0     0          3  ...
# 214       3659          1.0           0     0          3  ...
#
#      Change_In_Sqft_Plot  Listing_per_Zip_Code  Zipcode_Median_housePrice  \
# 0                   -654                   168                   765475.0
# 1                 -35773                   358                   260000.0
# 2                    477                   351                   309780.0
# 3                    283                   543                   446000.0
# 4                  -8037                   316                   689900.0
# ..                   ...                   ...                        ...
# 210                    0                   330                   315000.0
# 211                 -223                   411                   571000.0
# 212                  110                   431                   678000.0
# 213                 2171                   492                   269000.0
# 214                   47                   289                   574000.0
#
#      sqft_living_zipcode_ratio  sqft_lot_zipcode_ratio  \
# 0                     0.005623                0.010660
# 1                     0.004494                0.011951
# 2                     0.003646                0.000568
# 3                     0.001956                0.001364
# 4                     0.004800                0.016935
# ..                         ...                     ...
# 210                   0.003637                0.002803
# 211                   0.001218                0.000076
# 212                   0.003345                0.007754
# 213                   0.003817                0.001395
# 214                   0.002902                0.003613
#
#      sqft_above_zipcode_ratio  sqft_basement_zipcode_ratio  \
# 0                    0.006916                     0.000000
# 1                    0.004416                     0.005232
# 2                    0.003877                     0.000000
# 3                    0.001551                     0.004084
# 4                    0.006522                     0.000000
# ..                        ...                          ...
# 210                  0.002391                     0.008595
# 211                  0.001346                     0.000545
# 212                  0.003867                     0.000000
# 213                  0.003958                     0.002969
# 214                  0.001921                     0.007902
#
#      sqft_living15_zipcode_ratio  sqft_lot15_zipcode_ratio  \
# 0                       0.007325                  0.011354
# 1                       0.002378                  0.007048
# 2                       0.003558                  0.000656
# 3                       0.001829                  0.001631
# 4                       0.005607                  0.012626
# ..                           ...                       ...
# 210                     0.002579                  0.003043
# 211                     0.001269                  0.000069
# 212                     0.004121                  0.008232
# 213                     0.003603                  0.001954
# 214                     0.003153                  0.003604
#
#      sqft_median_price_zipcode_ratio
# 0                           1.175741
# 1                           1.615385
# 2                           1.097553
# 3                           1.102018
# 4                           2.717785
# ..                               ...
# 210                         1.063492
# 211                         0.577846
# 212                         1.786136
# 213                         1.349442
# 214                         0.818815
#
# [215 rows x 31 columns]

# %% [markdown]
# #### Data Preparation

# %%
y_test = X_test['Price']
X_test = X_test.drop(columns=['Price'], index= 1)

# %%
train_data = pd.read_csv(r'..\data\train_data.csv', index_col = 0)
train_data = train_data.reset_index()
y_train = train_data['Price']
X_train = train_data.drop(columns = ['index', 'Price'], axis = 1)

# %% [markdown]
# #### Fitting Final Model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('selectkbest',
#                  SelectKBest(k=10,
#                              score_func=<function f_regression at 0x0000012F0189E168>)),
#                 ('randomforestregressor',
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=None,
#                                        max_features='auto', max_leaf_nodes=None,
#                                        max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=16, n_jobs=None,
#                                        oob_score=False, random_state=1,
#                                        verbose=0, warm_start=False))],
#          verbose=False)

# %%
cv_results = cross_validate(model, X_train, y_train, scoring='r2', cv=5, n_jobs=-1)
cv_scores = cv_results['test_score']
cv_scores
# Out:
# array([0.99471513, 0.98130837, 0.98541493, 0.97103883, 0.99440846])

# %%
print("Mean Cross Validation Scores: ", np.mean(cv_scores))
print("Std of Cross Validation Scores: ", np.std(cv_scores))
# Out:
# Mean Cross Validation Scores:  0.9853771463849175
# Std of Cross Validation Scores:  0.008842016663800138

# %% [markdown]
# #### Applying on Test Data

# %%
y_te_pred = model.predict(X_test)

# %%
results = X_test
results['original price'] = y_test
results['model price'] = y_te_pred

# %%
results
# Out:
#              Id  Bedroom_Count  Bathroom_Count  Sqft_Living  Sqft_Plot  \
# 0    1445500100              5            2.25         2510      35691
# 2    7300400320              4            2.50         2810       6481
# 3     251200240              4            2.75         2100       7236
# 4    1025039086              3            2.50         3280      29111
# 5    1328300990              3            1.75         1530       7650
# ..          ...            ...             ...          ...        ...
# 210  4302200625              3            1.75         1790       5120
# 211  8562780290              2            2.25         1260       1032
# 212  1762600090              4            2.50         3430      35120
# 213  2867300190              4            2.50         3753       7204
# 214  5366200330              4            2.00         1500       3659
#
#      Floor_Count  Waterfront  View  Condition  Grade  ...  \
# 0            1.0           0     0          3      9  ...
# 2            2.0           0     0          3      9  ...
# 3            1.0           0     0          3      8  ...
# 4            2.0           1     3          3     11  ...
# 5            1.0           0     0          4      8  ...
# ..           ...         ...   ...        ...    ...  ...
# 210          1.0           0     0          4      6  ...
# 211          2.0           0     0          3      7  ...
# 212          2.0           0     0          3     10  ...
# 213          2.0           0     0          3     10  ...
# 214          1.0           0     0          3      7  ...
#
#      Zipcode_Median_housePrice  sqft_living_zipcode_ratio  \
# 0                     765475.0                   0.005623
# 2                     309780.0                   0.003646
# 3                     446000.0                   0.001956
# 4                     689900.0                   0.004800
# 5                     335000.0                   0.001651
# ..                         ...                        ...
# 210                   315000.0                   0.003637
# 211                   571000.0                   0.001218
# 212                   678000.0                   0.003345
# 213                   269000.0                   0.003817
# 214                   574000.0                   0.002902
#
#      sqft_lot_zipcode_ratio  sqft_above_zipcode_ratio  \
# 0                  0.010660                  0.006916
# 2                  0.000568                  0.003877
# 3                  0.001364                  0.001551
# 4                  0.016935                  0.006522
# 5                  0.000867                  0.001875
# ..                      ...                       ...
# 210                0.002803                  0.002391
# 211                0.000076                  0.001346
# 212                0.007754                  0.003867
# 213                0.001395                  0.003958
# 214                0.003613                  0.001921
#
#      sqft_basement_zipcode_ratio  sqft_living15_zipcode_ratio  \
# 0                       0.000000                     0.007325
# 2                       0.000000                     0.003558
# 3                       0.004084                     0.001829
# 4                       0.000000                     0.005607
# 5                       0.000000                     0.002072
# ..                           ...                          ...
# 210                     0.008595                     0.002579
# 211                     0.000545                     0.001269
# 212                     0.000000                     0.004121
# 213                     0.002969                     0.003603
# 214                     0.007902                     0.003153
#
#      sqft_lot15_zipcode_ratio  sqft_median_price_zipcode_ratio  \
# 0                    0.011354                         1.175741
# 2                    0.000656                         1.097553
# 3                    0.001631                         1.102018
# 4                    0.012626                         2.717785
# 5                    0.001094                         0.946269
# ..                        ...                              ...
# 210                  0.003043                         1.063492
# 211                  0.000069                         0.577846
# 212                  0.008232                         1.786136
# 213                  0.001954                         1.349442
# 214                  0.003604                         0.818815
#
#      original price   model price
# 0          900000.0  8.928675e+05
# 2          340000.0  3.367450e+05
# 3          491500.0  4.919438e+05
# 4         1875000.0  1.886656e+06
# 5          317000.0  3.173125e+05
# ..              ...           ...
# 210        335000.0  3.352305e+05
# 211        329950.0  3.302406e+05
# 212       1211000.0  1.213750e+06
# 213        363000.0  3.813383e+05
# 214        470000.0  4.666531e+05
#
# [214 rows x 32 columns]

# %%
path = r'..\Reports\results.csv'
results.to_csv(path)
